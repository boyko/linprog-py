# %% [markdown]
# An interactive example showing how the optimal production plan changes depending
# on the amount of resources available. The model solved in the figure below is:
#
# $$
# \begin{align}
# & x_1: \text{ Super espresso (kg)}\\
# & x_2: \text{ Deluxe espresso (kg)}
# \end{align}
# $$
#
# ressource
#
# $$
# \max z = 40 x_1 + 50 x_2 \text{ (objective)} \\
# \begin{align*}
#   0.5 x_1 + 0.25 x_2 & \leq 120 \text{ (Brazilian coffee)}\\
#   0.5 x_1 + 0.75 x_2 & \leq 160 \text{ (Cuban coffee)} \\
#   x_2 & \leq 150 \text{ (Demand for deluxe)}\\
#   x_1 & \geq 0 \\
#   x_2 & \geq 0
# \end{align*}
# $$

# %%
# %matplotlib widget

from ex1 import render_ex1

render_ex1()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
